# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# %%
train_1 = '/train.csv'
train = pd.read_csv(train_1)
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
train['SalePrice'].head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
#Removing All the rows where the saleprice is null
Target = 'SalePrice'
train.dropna(axis=0, subset=[Target], inplace=True)

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.iloc[:,:-1].shape
# Out:
# (1460, 80)

# %%
test_d = '/test.csv'
test = pd.read_csv(test_d)
test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
test.shape
# Out:
# (1459, 80)

# %%
#concatinating both the test and train datasets so as to clean as a whole
data =pd.concat([train.iloc[:,:-1],test],axis=0)
data.shape
# Out:
# (2919, 80)

# %%
2919-1459
# Out:
# 1460

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  ...  MoSold YrSold SaleType SaleCondition
# 0   1          60       RL         65.0  ...       2   2008       WD        Normal
# 1   2          20       RL         80.0  ...       5   2007       WD        Normal
# 2   3          60       RL         68.0  ...       9   2008       WD        Normal
# 3   4          70       RL         60.0  ...       2   2006       WD       Abnorml
# 4   5          60       RL         84.0  ...      12   2008       WD        Normal
#
# [5 rows x 80 columns]

# %%
data = data.drop(['Id'],axis=1)

# %%
data.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]

# %%
values = {}
def gaps(df):
    numerical = [label for label in df.columns if df[label].dtype in ['int64', 'float64']]
    category = [label for label in df.columns if df[label].dtype == "object"]
    for a in category:
        values[a] = 'novalue'

    for a in numerical:
        values[a] = df[a].median()
        
    df.fillna(value=values,inplace=True)
    
gaps(data)

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]

# %%
def objectcolumn(df):
    return [label for label in df.columns if df[label].dtype == "object"]

def dummies(df,columns):
    return pd.get_dummies(df,columns = columns)

category = objectcolumn(data)
df = dummies(data,category)
df.head()
# Out:
#    MSSubClass  LotFrontage  ...  SaleCondition_Normal  SaleCondition_Partial
# 0          60         65.0  ...                     1                      0
# 1          20         80.0  ...                     1                      0
# 2          60         68.0  ...                     1                      0
# 3          70         60.0  ...                     0                      0
# 4          60         84.0  ...                     1                      0
#
# [5 rows x 311 columns]

# %%
train1 = df.iloc[:1460,:]
test1 = df.iloc[1460:,:] #splitting back into individual datasets

# %%
X = train1
y = train['SalePrice']

# %%
param_grid = {'alpha': np.arange(0.01,1.5, dtype ='float')}

# %%
ridge = Ridge( normalize = True)

# %%
ridge_cv = GridSearchCV(ridge, param_grid,cv = 5)

# %%
ridge_cv.fit(X,y)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=True, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': array([0.01, 1.01])}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
y_pred  = ridge_cv.predict(test1)

# %%
ridge_cv.score(test1, y_pred)
# Out:
# 1.0

# %%
ridge_cv.best_params_
# Out:
# {'alpha': 1.01}
